# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('fake_job_postings.csv')

# %%
count_list = []
for i in df.columns:
        count_list.append((len(df[i].unique())))
count = pd.DataFrame({'Attribute': df.columns, 'Count': count_list})
print(count)
# Out:
#               Attribute  Count
# 0                job_id  17880
# 1                 title  11231
# 2              location   3106
# 3            department   1338
# 4          salary_range    875
# 5       company_profile   1710
# 6           description  14802
# 7          requirements  11969
# 8              benefits   6206
# 9         telecommuting      2
# 10     has_company_logo      2
# 11        has_questions      2
# 12      employment_type      6
# 13  required_experience      8
# 14   required_education     14
# 15             industry    132
# 16             function     38
# 17           fraudulent      2

# %%
df.isnull().sum()
# Out:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2695
# benefits                7210
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %%
ax = sns.countplot(x='fraudulent', data=df);

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.01))

plt.show()

# %%
plt.figure(figsize=(10,6))
    
ax = sns.countplot(x="telecommuting", data=df, hue="fraudulent",
              order=df["telecommuting"].value_counts().iloc[:10].index)

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))

plt.show()

# %%
plt.figure(figsize=(10,6))
ax = sns.countplot(x="has_company_logo", data=df, hue="fraudulent",
              order=df["has_company_logo"].value_counts().iloc[:10].index)

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))

plt.show()

# %%
plt.figure(figsize=(10,6))
ax = sns.countplot(x="has_questions", data=df, hue="fraudulent",
              order=df["has_questions"].value_counts().iloc[:10].index)

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))

plt.show()

# %%
plt.figure(figsize=(10,6))
ax = sns.countplot(x="employment_type", data=df, hue="fraudulent",
              order=df["employment_type"].value_counts().iloc[:10].index)

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+0.01))

plt.show()

# %%
plt.figure(figsize=(10,6))
ax = sns.countplot(x="required_experience", data=df, hue="fraudulent",
              order=df["required_experience"].value_counts().iloc[:10].index)

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.01))

plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
ax = sns.countplot(x="required_education", data=df, hue="fraudulent",
              order=df["required_education"].value_counts().iloc[:10].index)

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.01))

plt.show()

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
ax = sns.countplot(x="industry", data=df, hue="fraudulent",
              order=df["industry"].value_counts().iloc[:15].index)

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.01))

plt.show()

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
ax = sns.countplot(x="function", data=df, hue="fraudulent",
              order=df["function"].value_counts().iloc[:15].index)

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.01))

plt.show()

# %%
real_job_postings = df[df['fraudulent']==0]
fake_job_postings = df[df['fraudulent']==1]

# %%
import os

from os import path
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Read the text in the attribute "title"
fake_title = str(fake_job_postings["title"])
real_title = str(real_job_postings["title"])

# Generate a word cloud image for fake job postings
wordcloud1 = WordCloud().generate(fake_title)
plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis("off")

# Generate a word cloud image for real job postings
wordcloud2 = WordCloud().generate(real_title)
plt.figure()
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# lower max_font_size
#wordcloud = WordCloud(max_font_size=40).generate(text)
#plt.figure()
#plt.imshow(wordcloud, interpolation="bilinear")
#plt.axis("off")
#plt.show()

# %%
# Read the text in the attribute "description"
fake_description = str(fake_job_postings["description"])
real_description = str(real_job_postings["description"])

# Generate a word cloud image for fake job postings
wordcloud1 = WordCloud().generate(fake_description)
plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis("off")

# Generate a word cloud image for real job postings
wordcloud2 = WordCloud().generate(real_description)
plt.figure()
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Read the text in the attribute "requirements"
fake_requirements = str(fake_job_postings["requirements"])
real_requirements = str(real_job_postings["requirements"])

# Generate a word cloud image for fake job postings
wordcloud1 = WordCloud().generate(fake_requirements)
plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis("off")

# Generate a word cloud image for real job postings
wordcloud2 = WordCloud().generate(real_requirements)
plt.figure()
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
#df = pd.read_csv("fake_job_postings.csv")
text_cols = ["title", "company_profile", "description", "requirements", "benefits","fraudulent"]
text_df = df.loc[:,text_cols]
for cols in range(1,5):
  text_df = df.loc[:,[text_cols[cols], "fraudulent"]]
  text_df['word_count'] = text_df[text_cols[cols]].apply(lambda x: len(str(x).split(" ")))
  text_df['sentence_count'] = text_df[text_cols[cols]].apply(lambda x: len(str(x).split(".")))
  #text_df['avg_sentence_lenghth'] = text_df['word_count'] / text_df['sentence_count']
  #print(text_df)

  features = ['word_count','sentence_count']#,'avg_sentence_lenghth']
  y = 'fraudulent'

  fig, ax = plt.subplots(nrows=2, ncols=2,figsize=(10, 10), dpi=100)

  fig.suptitle(text_cols[cols],y = 0.9, fontsize=15)
  for f in range(2):
    x = features [f]
    for i in text_df[y].unique():
      sns.distplot(text_df[text_df[y]==i][x], hist=True, kde=False, 
                    bins=10, hist_kws={"alpha":0.6}, 
                    axlabel=x+"_histogram", ax=ax[f,0])
      sns.distplot(text_df[text_df[y]==i][x], hist=False, kde=True, 
                    kde_kws={"shade":True}, axlabel=x+"_density",   
                    ax=ax[f,1])
    ax[f,0].grid(True)
    ax[f,0].legend(text_df[y].unique())
    ax[f,1].grid(True)
  plt.show()
